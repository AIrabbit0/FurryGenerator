# %% [markdown]
# <a href="https://colab.research.google.com/github/AIrabbit0/FurryGenerator/blob/main/GeneradorDeFurros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Generador de Furros - v1.0**
# Este cuaderno fue realizado con la finalidad de que pueden usar los modelos de stable Diffusion de una forma sencilla y práctica.
#
# Las herramientas usadas en el cuaderno fueron basados de los repositorios de github de [camenduru](https://github.com/camenduru) y [nolanaatama](https://github.com/nolanaatama).
#
# El cuaderno fue desarrollado por [AIrabbit0](https://github.com/AIrabbit0/FurryGenerator), para los usuarios del [grupo](https://www.facebook.com/groups/429481779336019) y la [pagina](https://www.facebook.com/profile.php?id=100086789162708) de Dibujos Furry Hechos por una IA.
#
# Además el cuaderno se actualizará peridócamente, ya que ciertos componente pueden fallar al momento que se actualice el cuaderno, en dado caso se recomienda esperar o hacer una copia previa.

# %% [markdown]
# # **Para empezar**
# El cuaderno se conforma de tres secciones o celdas:
#
# * La primera celda permite descargar los archivos para el entorno de la interfaz web, además de descargar los modelos de imágenes generativas como los archivo LoRA.
#
# * La segunda celda es una celda opcional y permite al usuario cargar archivos desde Google Drive al entorno.
#
# * Y la tercera celda permite ejecutar el entorno desplegando la interfaz gráfica.
#
# Si eres principiante se recomienda ejecutar las celdas número uno y número tres.
#
# Los **modelos** son archivos que contiene la información para generar imágenes, es decir sin un modelo no se podría generar imágenes.
#
# Este cuaderno proporciona varios modelos para generar imágenes, desde tipo anime hasta furry, selecciona el modelo de preferencia y comienza a jugar que imagen(es) vas a generar.
#
# Nota: Cada modelo es distinto con diferentes estilos ya se por los data sets que utilizaron asi como la mejora entre versiones de un mismo modelo a otro.
#
# Como complemento algunos modelos pueden generar imágenes más opacas o sin colores vividos por lo que se recomienda usar un archivo **VAE**.
#
# Para más información, recursos o consultas, visitar la wiki del cuaderno. [Aquí](https://github.com/AIrabbit0/FurryGenerator/wiki)

# %% [markdown]
# # **1. Cargar el entorno de la IA**
#
#
# 1. Seleccione el modelo que va a utilizar, (Opcionalmente puede seleccionar un lora si sabe cómo usarlo).
#
# 2. Presione el play (▶) y espere que se cargue los componentes para pasar a la siguiente casilla.
#
# 3. Una vez que los archivos se hayan descargado dirigirse a la ultima casilla (número tres), para desplegar el entorno.

# %%
#@markdown{ vertical-output: true, display-mode: "form" }

# %cd /content
import os
import shutil
from google.colab.output import eval_js
os.environ['colab_url'] = eval_js("google.colab.kernel.proxyPort(7860, {'cache': false})")

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !apt -y install -qq aria2
# !pip install -q xformers==0.0.16
# !pip install -q triton==2.0.0

# !git clone -b v2.1 https://github.com/camenduru/stable-diffusion-webui
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O /content/stable-diffusion-webui/scripts/run_n_times.py

os.mkdir('/content/stable-diffusion-webui/models/Lora/')
os.mkdir('/content/stable-diffusion-webui/models/hypernetworks/')

#Extensiones
#3D Pose
# !git clone https://github.com/nonnonstop/sd-webui-3d-open-pose-editor /content/stable-diffusion-webui/extensions/sd-webui-3d-open-pose-editor
#ABG-Extension
# !git clone https://github.com/KutsuyaYuki/ABG_extension /content/stable-diffusion-webui/extensions/ABG_extension
#Additional Networks
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
#AdvanceCleaner
# !git clone https://github.com/gogodr/AdverseCleanerExtension  /content/stable-diffusion-webui/extensions/AdverseCleanerExtension
#Batchlinks
# !git clone https://github.com/etherealxx/batchlinks-webui /content/stable-diffusion-webui/extensions/batchlinks-webui
#Catpuccin
# !git clone https://github.com/camenduru/stable-diffusion-webui-catppuccin /content/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin
#Compesable LoRA
# !git clone https://github.com/opparco/stable-diffusion-webui-composable-lora /content/stable-diffusion-webui/extensions/stable-diffusion-webui-composable-lora
#ControlNet
# !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
#CuttOff
# !git clone https://github.com/hnmr293/sd-webui-cutoff /content/stable-diffusion-webui/extensions/sd-webui-cutoff
#Deforum
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
#Depth-lib
# !git clone https://github.com/jexom/sd-webui-depth-lib /content/stable-diffusion-webui/extensions/sd-webui-depth-lib
#Image Browser
# !git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
#LonCon
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon /content/stable-diffusion-webui/extensions/a1111-sd-webui-locon
#LLUL
# !git clone https://github.com/hnmr293/sd-webui-llul /content/stable-diffusion-webui/extensions/sd-webui-llul
#NovelAI-2-Local-Prompt
# !git clone https://github.com/animerl/novelai-2-local-prompt /content/stable-diffusion-webui/extensions/novelai-2-local-prompt
#Posex
# !git clone https://github.com/hnmr293/posex /content/stable-diffusion-webui/extensions/posex
#Tag-Complete
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete /content/stable-diffusion-webui/extensions/tag-autocomplete
#Two-shots
# !git clone -b feature/mask_selection https://github.com/ashen-sensored/stable-diffusion-webui-two-shot /content/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot
#Tunnels
# !git clone https://github.com/camenduru/sd-webui-tunnels /content/stable-diffusion-webui/extensions/sd-webui-tunnels

#ControlNet
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_canny-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_depth-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_hed-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_mlsd-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_normal-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_openpose-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_scribble-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_seg-fp16.safetensors  https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors

#Adapters
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_style_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_style_sd14v1.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_sketch_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_sketch_sd14v1.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_seg_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_seg_sd14v1.pth  
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_openpose_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_openpose_sd14v1.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_keypose_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_keypose_sd14v1.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_depth_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_depth_sd14v1.pth  
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_color_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_color_sd14v1.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_canny_sd14v1.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_canny_sd14v1.pth  

#Otros
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose/hand_pose_model.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose/body_pose_model.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/midas/dpt_hybrid-midas-501f0c75.pt  https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/mlsd_large_512_fp32.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/mlsd_tiny_512_fp32.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/hed/network-bsds500.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/upernet_global_small.pth  https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth

shutil.rmtree('/content/stable-diffusion-webui/embeddings')
# %cd /content/stable-diffusion-webui
# !git clone https://huggingface.co/nolanaatama/embeddings
# !git reset --hard

#@markdown ##**Modelos**
#@markdown Seleccione su modelo **marcando** la casilla. _Recomendación 3 a 4 modelos, ya que se puede quedar si espacio en el disco del entorno_

#@markdown **Modelos anything** (anime)
Anythingv3 = False #@param{type:"boolean"}
Anythingv4 = False #@param{type:"boolean"}
Anythingv4_5 = False #@param{type:"boolean"}

#@markdown ---

#@markdown **Modelos abyss-2** (anime y furry)
AbyssOrangeMix2_nsfw = False #@param{type:"boolean"}
AbyssOrangeMix2_hard = False #@param{type:"boolean"}
OrangeCocoaMix2_hard = False #@param{type:"boolean"}

#@markdown ---

#@markdown **Modelos abyss-3** (anime y furry)
AOM3 = False #@param{type:"boolean"}
AOM3A1 = False #@param{type:"boolean"}
AOM3A2 = False #@param{type:"boolean"}
AOM3A3 = False #@param{type:"boolean"}

#@markdown ---

#@markdown **Modelos furry**
Crosskemono = False #@param{type:"boolean"}
Lawlas = False #@param{type:"boolean"}
Lawlas2 = False #@param{type:"boolean"}
LucidMix = False #@param{type:"boolean"}
PonyDiffusion = False #@param{type:"boolean"}
SomeFurryMix = False #@param{type:"boolean"}
YiffyMix = False #@param{type:"boolean"}
Yiff_e18 = False #@param{type:"boolean"}
YiffProtosaber = False #@param{type:"boolean"}

#@markdown ---
#@markdown **Seleccione** el LoRA a descargar

AnthroBirds = False #@param{type:"boolean"}
Aviali = False #@param{type:"boolean"}
Cobras = False #@param{type:"boolean"}
Cockatiel = False #@param{type:"boolean"}
DianeFoxington = False #@param{type:"boolean"}
Griffin = False #@param{type:"boolean"}
FeatheredRaptors = False #@param{type:"boolean"}
Ferrin = False #@param{type:"boolean"}
Lola = False #@param{type:"boolean"}
Loona = False #@param{type:"boolean"}
Michiru = False #@param{type:"boolean"}
Nicole = False #@param{type:"boolean"}
NJfurry = False #@param{type:"boolean"}
Protogen = False #@param{type:"boolean"}
Puffin = False #@param{type:"boolean"}
TweetFur = False #@param{type:"boolean"}
Shikabane = False #@param{type:"boolean"}

##Descargar archivo(s)

#Anything
if Anythingv3:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/anythingv3.ckpt https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0-pruned.ckpt
if Anythingv4:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/anythingv4.ckpt https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt
if Anythingv4_5:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/anythingv4.5.ckpt https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.ckpt

#Abyss 2
if AbyssOrangeMix2_nsfw:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix2_nsfw.safetensors https://huggingface.co/ckpt/OrangeMixs/resolve/main/AbyssOrangeMix2_nsfw.safetensors
if AbyssOrangeMix2_hard:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix2_hard.safetensors https://huggingface.co/ckpt/OrangeMixs/resolve/main/AbyssOrangeMix2_hard.safetensors
if OrangeCocoaMix2_hard:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/OrangeCocoaMix2_hard.safetensors https://huggingface.co/ckpt/OrangeCocoaMix/resolve/main/OrangeCocoaMix2_hard.safetensors

#Abyss 3
if AOM3:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/AOM3.safetensors https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3.safetensors
if AOM3A1:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/AOM3A1.safetensors https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A1.safetensors
if AOM3A2:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/AOM3A2.safetensors https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A2.safetensors
if AOM3A3:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/AOM3A3.safetensors https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A3.safetensors

#Furry
if Crosskemono:
  # !wget https://civitai.com/api/download/models/14575 -O /content/stable-diffusion-webui/models/Stable-diffusion/crosskemonoC.safetensors
  # !wget https://civitai.com/api/download/models/20242 -O /content/stable-diffusion-webui/models/Stable-diffusion/crosskemonoE.safetensors
  # !wget https://civitai.com/api/download/models/17114 -O /content/stable-diffusion-webui/models/hypernetworks/furrykemono.pt 
if FurryVixens
  # !wget https://civitai.com/api/download/models/24209 -O /content/stable-diffusion-webui/models/hypernetworks/furryvixens.safetensors
if Lawlas:
  # !wget https://civitai.com/api/download/models/5370 -O /content/stable-diffusion-webui/models/Stable-diffusion/lawlas.safetensors
if Lawlas2:
  # !wget https://civitai.com/api/download/models/15288 -O /content/stable-diffusion-webui/models/Stable-diffusion/lawlas2.safetensors
if LucidMix:
  # !wget https://civitai.com/api/download/models/9540 -O /content/stable-diffusion-webui/models/Stable-diffusion/lucidMix.safetensors
if PonyDiffusion:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/PonyDiffusion.safetensors https://huggingface.co/AstraliteHeart/pony-diffusion-v4/resolve/main/safetensors/pony_v4.safetensors
if SomeFurryMix:
  # !wget https://civitai.com/api/download/models/10376 -O /content/stable-diffusion-webui/models/Stable-diffusion/someFurryMix.safetensors
if YiffyMix:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/yiffymix.safetensors https://huggingface.co/ckpt/yiffymix/resolve/main/yiffymix.safetensors  
if Yiff_e18:
  # !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/yiff-e18.ckpt https://huggingface.co/ckpt/yiffy-e18/resolve/main/yiffy-e18.ckpt
if YiffProtosaber:
  # !wget https://civitai.com/api/download/models/10293 -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffProtosaber.safetensors

#Descargar LoRA
if AnthroBirds: 
  # !wget https://civitai.com/api/download/models/11425 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/anthrobirds.safetensors
if Aviali:
  # !wget https://civitai.com/api/download/models/23477 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/aviali.safetensors
if Cobras:
  # !wget https://civitai.com/api/download/models/23291 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/cobras.safetensors
if Cockatiel:
  # !wget https://civitai.com/api/download/models/11446 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/cockatiel.safetensors
if DianeFoxington:
  # !wget https://civitai.com/api/download/models/12828 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/diane.safetensors
if Griffin: 
  # !wget https://civitai.com/api/download/models/11445 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/griffin.safetensors
if FeatheredRaptors: 
  # !wget https://civitai.com/api/download/models/25292 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/featheredraptors.safetensors
if Ferrin: 
  # !wget https://civitai.com/api/download/models/28550 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/frrin.safetensors
if Lola:
  # !wget https://civitai.com/api/download/models/22696 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/lola.safetensors
if Loona:
  # !wget https://civitai.com/api/download/models/9149 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/loona.safetensors
if Protogen: 
  # !wget https://civitai.com/api/download/models/18651 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/protogen.safetensors
if Puffin: 
  # !wget https://civitai.com/api/download/models/11432 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/puffin.safetensors
if Nicole:
  # !wget https://civitai.com/api/download/models/21680 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/nicole.safetensors
if NJfurry: 
  # !wget https://civitai.com/api/download/models/12654 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/NJfurry.safetensors
if Michiru:
  # !wget https://civitai.com/api/download/models/10557 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/michiru.safetensors
if TweetFur: 
  # !wget https://civitai.com/api/download/models/11442 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/tweetfur.safetensors
if Shikabane:
  # !wget https://civitai.com/api/download/models/22820 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/shikabane.safetensors

#Cargar VAE
# !curl -Lo /content/stable-diffusion-webui/models/VAE/anythingv3.vae.pt https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt
# !curl -Lo /content/stable-diffusion-webui/models/VAE/anythingv4.5.vae.pt https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt
# !curl -Lo /content/stable-diffusion-webui/models/VAE/wd1.4.vae.pt  https://huggingface.co/ckpt/waifu-diffusion-v1-4/resolve/main/kl-f8-anime2.ckpt

# %% [markdown]
# # **2. Opcional cargue archivos desde Google Drive al entorno**

# %%
#@markdown ##**Establecer conexion a google drive**
#@markdown Esta celda permite establecer una conexión entre el entorno y su almacenamiento en la nube para importar archivos.
#@markdown Una vez establecida la conexión dirigirse a la celda para ingresar sus archivos desde drive.
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## **Como agregar archivos desde drive**
#
# Si eres nuevo, te recomendamos saltar esta celda si ya tienes más experiencia usando entornos de colab adelante sube tus archivos personalizados.
#
# 1.	Abra la carpeta de archivos de colab, que está en la barra lateral izquierda 📁
# 2.	Busque su carpeta Drive y despliegue las carpetas que están adentro.
# 3.	Marque el número de archivos que va a importar.
# 4.	Click derecho sobre el archivo a importar y copie la ruta junto con la extensión del archivo. Ejemplo: MyDrive/content/modelo.ckpt
# 5.	Seleccione que tipo de archivo es si es modelo, lora, hypernetwork, embedding. Esto para que el archivo se guarde en la carpeta correcta.
# 6.	Presione el play (▶) y espere que se cargue los componentes para pasar a la siguiente casilla.
#
#
# Para una guia mas extensa visitar la wiki. [Aquí](https://github.com/AIrabbit0/FurryGenerator/wiki)

# %%
#@markdown ##**Ingrese sus archivos de google drive**
#@markdown **Marque la casilla(s)** según el número de archivos  a cargar.
#@markdown _Si desea agregar más archivos desde civitai/mega/hugginface favor de usar la extension de batchlinks_.

#@markdown ---
#@markdown ###**Archivo uno**

archivo_uno = False #@param {type:"boolean"}

ruta_uno = "" #@param {type:"string"}

#@markdown **Marque** que tipo de archivo es: Modelo, LoRA, Hypernetwork o Embedding/Textual inversor 

modelo_uno = False #@param {type:"boolean"}
lora_uno = False #@param {type:"boolean"}
hypernetwork_uno = False #@param {type:"boolean"}
embedding_uno = False #@param {type:"boolean"}

#@markdown ---
#@markdown ###**Archivo dos**

archivo_dos = False #@param {type:"boolean"}
ruta_dos = "" #@param {type:"string"}
#@markdown Marque que tipo de archivo es Modelo, LoRA, Hypernetwork o Embeding/Textual inversor 

modelo_dos = False #@param {type:"boolean"}
lora_dos = False #@param {type:"boolean"}
hypernetwork_dos = False #@param {type:"boolean"}
embedding_dos = False #@param {type:"boolean"}

#@markdown ---
#@markdown ###**Archivo tres**

archivo_tres = False #@param {type:"boolean"}
ruta_tres = "" #@param {type:"string"}

#@markdown Marque que tipo de archivo es Modelo, LoRA, Hypernetwork o Embedding/Textual inversor 

modelo_tres = False #@param {type:"boolean"}
lora_tres = False #@param {type:"boolean"}
hypernetwork_tres = False #@param {type:"boolean"}
embedding_tres = False #@param {type:"boolean"}

#@markdown ---
#@markdown ###**Archivo cuatro**

archivo_cuatro = False #@param {type:"boolean"}
ruta_cuatro = "" #@param {type:"string"}

#@markdown Marque que tipo de archivo es Modelo, LoRA, Hypernetwork o Embedding/Textual inversor 

modelo_cuatro = False #@param {type:"boolean"}
lora_cuatro = False #@param {type:"boolean"}
hypernetwork_cuatro = False #@param {type:"boolean"}
embedding_cuatro = False #@param {type:"boolean"}

#@markdown ---
#@markdown ###**Archivo cinco**

archivo_cinco = False #@param {type:"boolean"}
ruta_cinco = "" #@param {type:"string"}

#@markdown Marque que tipo de archivo es Modelo, LoRA, Hypernetwork o Embedding/Textual inversor 

modelo_cinco = False #@param {type:"boolean"}
lora_cinco = False #@param {type:"boolean"}
hypernetwork_cinco = False #@param {type:"boolean"}
embedding_cinco = False #@param {type:"boolean"}

#@markdown ---

#Ruta uno
if archivo_uno:

  if modelo_uno:
    # !cp {ruta_uno} /content/stable-diffusion-webui/models/Stable-diffusion

  elif lora_uno:
    # !cp {ruta_uno} /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

  elif hypernetwork_uno:
    # !cp {ruta_uno} /content/stable-diffusion-webui/models/hypernetworks

  elif embedding_uno:
    # !cp {ruta_uno} /content/stable-diffusion-webui/embeddings

  else:
    print("No marco el tipo de archivo")

#Ruta 2

if archivo_dos:

  if modelo_dos:
    # !cp {ruta_dos} /content/stable-diffusion-webui/models/Stable-diffusion

  elif lora_dos:
    # !cp {ruta_dos} /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

  elif hypernetwork_dos:
    # !cp {ruta_dos} /content/stable-diffusion-webui/models/hypernetworks

  elif embedding_dos:
    # !cp {ruta_dos} /content/stable-diffusion-webui/embeddings

  else:
    print("No marco el tipo de archivo")

#Ruta 3

if archivo_tres:

  if modelo_tres:
    # !cp {ruta_tres} /content/stable-diffusion-webui/models/Stable-diffusion

  elif lora_tres:
    # !cp {ruta_tres} /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

  elif hypernetwork_tres:
    # !cp {ruta_tres} /content/stable-diffusion-webui/models/hypernetworks

  elif embedding_tres:
    # !cp {ruta_tres} /content/stable-diffusion-webui/embeddings

  else:
    print("No marco el tipo de archivo")

#Ruta 4

if archivo_cuatro:

  if modelo_cuatro:
    # !cp {ruta_cuatro} /content/stable-diffusion-webui/models/Stable-diffusion

  elif lora_cuatro:
    # !cp {ruta_cuatro} /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

  elif hypernetwork_cuatro:
    # !cp {ruta_cuatro} /content/stable-diffusion-webui/models/hypernetworks

  elif embedding_cuatro:
    # !cp {ruta_cuatro} /content/stable-diffusion-webui/embeddings

  else:
    print("No marco el tipo de archivo")

#Ruta cinco

if archivo_cinco:

  if modelo_cinco:
        # !cp {ruta_cinco} /content/stable-diffusion-webui/models/Stable-diffusion

  elif lora_cinco:
    # !cp {ruta_cinco} /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

  elif hypernetwork_cinco:
    # !cp {ruta_cinco} /content/stable-diffusion-webui/models/hypernetworks

  elif embedding_cinco:
    # !cp {ruta_cinco} /content/stable-diffusion-webui/embeddings

  else:
    print("No marco el tipo de archivo")

# %% [markdown]
# # **3. Desplegar el entorno**
# 1.	Presione el play (▶), en la celda de iniciar entorno, para que se ejecute y despliegue la WebUI.
#
# 2.	Al final mostrara tres enlaces, estos enlaces permiten desplegar la vista para usar la interfaz gráfica y pueda generar sus imágenes con más facilidad.
#
# 3.	Selecciones cualquiera de los dos últimos enlaces para abrir la interfaz.
# ![Ejemplo](https://dochub.com/rabbit0bot/275eAYrVo3JjjnMVzXnBNQ/link-png?dt=s7zS8X3s9xtfmqkXWcBD)
# 4.	¡Diviértase!
#
# **Nota**: *Si hay un error de desconexión, detener y ejecutar esta misma celda otra vez.*

# %%
#@title Iniciar entorno
#@markdown _La carga para el entorno puede tardar de 5 a 10 minutos._

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !sed -i -e 's/fastapi==0.94.0/fastapi==0.89.1/g' /content/stable-diffusion-webui/requirements_versions.txt

# !mkdir /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui/models

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple

# %% [markdown]
# # Wiki
#
# Para más información ir a la wiki, con guías sobre mas información de los modelos generativos, conceptos básicos, como usar las vistas o extensiones, personalizar el entorno, así como recursos y tutoriales de gente con experiencia. [Aquí](https://github.com/AIrabbit0/FurryGenerator/wiki)
